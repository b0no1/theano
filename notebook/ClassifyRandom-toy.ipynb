# %%
import theano
import theano.tensor as T
import numpy as np
rng = np.random

N = 400
feats = 784
D = (rng.randn(N,feats),rng.randint(size=N,low=0,high=2))
training_steps = 10000


x = T.matrix('x')
y = T.vector('y')
w = theano.shared(rng.randn(feats),'w')
b = theano.shared(0.,'b') # 0. makes b a float

p_1 = 1/(1 + T.exp(-T.dot(x,w) -b))
prediction = p_1 > 0.5 # will be true if p_1 > 0.5
# entropy function
xent = -y * T.log(p_1) - (1-y) * T.log(1-p_1)

# cost function
cost = xent.mean() + 0.01*(w**2).sum()
# gradients
gw,gb = T.grad(cost,[w,b])

# compile function
train = theano.function(inputs=[x,y],outputs=[prediction,xent],
                       updates = [(w , w - (0.1*gw)), (b , b - (0.1 *gb))])
predict = theano.function([x],prediction)

from theano.printing import pydotprint as _
_(train,'train.png')
_(predict,'predict.png')

import theano.d3viz as d3v
d3v.d3viz(predict, 'predict.html')

'''
# Train
for i in range(training_steps):
    pred, err = train(D[0], D[1])

print("Final model:")
print(w.get_value())
print(b.get_value())
print("target values for D:")
print(D[1])
print("prediction on D:")
print(predict(D[0]))
'''
# Out:
# The output file is available at train.png
# The output file is available at predict.png
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-3-43dfbd790ef1> in <module>()
#      34 _(predict,'predict.png')
#      35
# ---> 36 import theano.d3viz as d3v
#      37 d3v.d3viz(predict, 'predict.html')
#      38
#
# ImportError: No module named d3viz

# %%
import numpy
import theano
import theano.tensor as T
rng = numpy.random

N = 400
feats = 784
D = (rng.randn(N, feats), rng.randint(size=N, low=0, high=2))
training_steps = 10000

# Declare Theano symbolic variables
x = T.matrix("x")
y = T.vector("y")
w = theano.shared(rng.randn(feats), name="w")
b = theano.shared(0., name="b")
print("Initial model:")
print(w.get_value())
print(b.get_value())

# Construct Theano expression graph
p_1 = 1 / (1 + T.exp(-T.dot(x, w) - b))   # Probability that target = 1
prediction = p_1 > 0.5                    # The prediction thresholded
xent = -y * T.log(p_1) - (1-y) * T.log(1-p_1) # Cross-entropy loss function
cost = xent.mean() + 0.01 * (w ** 2).sum()# The cost to minimize
gw, gb = T.grad(cost, [w, b])             # Compute the gradient of the cost
                                          # (we shall return to this in a
                                          # following section of this tutorial)

# Compile
train = theano.function(
          inputs=[x,y],
          outputs=[prediction, xent],
          updates=((w, w - 0.1 * gw), (b, b - 0.1 * gb)))
predict = theano.function(inputs=[x], outputs=prediction)

# Train
for i in range(training_steps):
    pred, err = train(D[0], D[1])

predicted = predict(D[0])

print predicted - D[1]
# Out:
# Initial model:
# [ -1.49207164e+00  -5.42736039e-02  -1.02141814e+00  -1.44087503e+00
#    1.23237785e+00  -2.45736309e-01  -7.46862520e-01  -4.64092351e-01
#   -5.13285680e-01   7.48355044e-01   3.99970724e-01  -5.28683948e-01
#   -4.93085515e-01   1.46984680e-01  -5.97424984e-01  -6.69042556e-01
#   -7.79293867e-01  -1.16416078e+00  -1.75734960e+00   7.29099653e-01
#    3.25023099e-01   8.29656945e-01  -5.56663425e-01   1.20050088e+00
#   -7.71707253e-01  -1.73693876e-01   6.60351080e-01   1.16392803e+00
#    4.92124671e-01  -6.06259949e-02  -1.00795011e+00  -1.44867145e-01
#    1.48594373e+00  -7.63481625e-01   1.03873678e+00   1.17200705e+00
#    1.90486388e-01  -2.41120771e-01  -9.07138806e-01  -2.43815401e-01
#   -2.87105062e-01  -3.32667790e-01  -4.64524009e-01  -1.00107291e+00
#    1.25064024e+00  -6.69558098e-01  -9.21649805e-01  -5.86740694e-01
#   -1.53670018e+00  -9.90255495e-01  -6.12312564e-01  -6.70718842e-01
# ...
